# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
safe = pd.read_csv("timecorssim_SAFE.csv")

# %%
plt.scatter(safe.b1.values, safe.b2.values)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
temp = pd.read_csv("template.csv")
spec = pd.read_csv("chrissim_100.csv")

# %%
plt.plot(temp.Wavelength.values, temp.Flux.values)
plt.plot(spec.Wavelength.values, spec.Flux.values)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
